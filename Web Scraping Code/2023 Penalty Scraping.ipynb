# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.nflpenalties.com/all-players.php?view=reg_season&year=2023'

# Call the GET request
requests = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(requests.text, "html.parser")

# examined HTML output using inspect to find where data is
columns = ['Name', 'Position', 'Team', 'Penalty Count', 'Yards', 'Declined', 'Offsetting', 'Total Flags', 'Pre-Snap', 'Count per Game', 'Yards per Game', 'Percent of Team', 'Penalty Types']
player_penalties_df_2023 = pd.DataFrame(columns = columns)

penalties_div = soup.find(name = 'div', attrs = {'class' : 'inner'})
table = penalties_div.find("table") 
tbody = table.find("tbody")  # Get the tbody element
rows = tbody.find_all("tr")  # Find all table rows

for row in rows:
    cols = row.find_all("td")  # Get all table data cells
    data = [col.text.strip() for col in cols]  # Extract text from each column
    penalty_series = pd.Series(data, index = columns)
    player_penalties_df_2023 = pd.concat([player_penalties_df_2023, penalty_series.to_frame().T], ignore_index=True)

display(player_penalties_df_2023)

player_penalties_df_2023.to_csv("2023_Player_Penalties.csv", index = False)
print("Data saved to 2023_Player_Penalties.csv")
# Out:
#             Name Position         Team Penalty Count Yards Declined  \
# 0       J.Taylor       OL  Kansas City            17   115        2
# 1        L.Sneed       DB  Kansas City            11    82        6
# 2      Tyl.Smith       OL       Dallas            10    80        1
# 3      L.Goedeke       OL    Tampa Bay            10    73        3
# 4       M.Becton       OL    N.Y. Jets            12    84        0
# ..           ...      ...          ...           ...   ...      ...
# 259   M.Bergeron       OL      Atlanta             4    20        0
# 260     T.Palmer       WR    Tampa Bay             4    35        0
# 261    J.Bennett       DB    Las Vegas             4    43        0
# 262   W.Anderson       DL      Houston             4    44        0
# 263  T.Tomlinson       DB      LA Rams             4    34        0
#
#     Offsetting Total Flags Pre-Snap Count per Game Yards per Game  \
# 0            0          19       11           0.81           5.48
# 1            0          17        0           0.52           3.90
# 2            2          13        2           0.56           4.44
# 3            0          13        5           0.53           3.84
# 4            0          12        8           0.71           4.94
# ..         ...         ...      ...            ...            ...
# 259          0           4        3           0.24           1.18
# 260          0           4        1           0.21           1.84
# 261          0           4        0           0.24           2.53
# 262          0           4        1           0.21           2.32
# 263          0           4        0           0.22           1.89
#
#     Percent of Team                                      Penalty Types
# 0             16.96  False Start (8), Offensive Holding (7), Illega...
# 1             15.18  Defensive Pass Interference (8), Defensive Hol...
# 2             10.74  Offensive Holding (9), False Start (2), Unnece...
# 3             11.82             Offensive Holding (8), False Start (5)
# 4              9.60  False Start (8), Offensive Holding (3), Unnece...
# ..              ...                                                ...
# 259            4.76     False Start (3), Ineligible Downfield Pass (1)
# 260            3.64             Offensive Holding (3), False Start (1)
# 261            5.33  Defensive Pass Interference (3), Defensive Hol...
# 262            3.13  Roughing the Passer (2), Defensive Offside (1)...
# 263            4.30  Offensive Holding (1), Illegal Contact (1), Un...
#
# [264 rows x 13 columns]
# Data saved to 2023_Player_Penalties.csv
