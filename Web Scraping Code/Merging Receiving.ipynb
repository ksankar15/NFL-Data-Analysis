# %%
import numpy as np
import pandas as pd
receiving_2019 = pd.read_csv('Receiving_2019.csv')
receiving_2020 = pd.read_csv('Receiving_2020.csv')
receiving_2021 = pd.read_csv('Receiving_2021.csv')
receiving_2022 = pd.read_csv('Receiving_2022.csv')
receiving_2023 = pd.read_csv('Receiving_2023.csv')
receiving_2024 = pd.read_csv('Receiving_2024.csv')

# %%
total_receiving = pd.concat([receiving_2019, receiving_2020, receiving_2021, receiving_2022, receiving_2023, receiving_2024], axis=0)
total_receiving
# Out:
#      Rank             Name Team Position  Games Played  Receptions  \
# 0       1   Michael Thomas   NO       WR            16         149
# 1       2      Julio Jones  ATL       WR            15          99
# 2       3     Chris Godwin   TB       WR            14          86
# 3       4     Travis Kelce   KC       TE            16          97
# 4       5   DeVante Parker  MIA       WR            16          72
# ..    ...              ...  ...      ...           ...         ...
# 475   494  Brycen Tremayne  WSH       WR             2           1
# 476   494      Tyler Badie  DEN       RB             3           3
# 477   494     Zach Frazier  PIT        C            15           0
# 478   498    Dominick Puni   SF        G            17           0
# 479   500  Trevor Lawrence  JAX       QB            10           0
#
#      Receiving Targets Receiving Yards  Avg Yards per Reception  \
# 0                  185           1,725                     11.6
# ...

# %%
total_receiving.to_csv("Total_Receiving.csv", index = False)
print("Data saved to Total_Receiving.csv")
# Out:
# Data saved to Total_Receiving.csv
