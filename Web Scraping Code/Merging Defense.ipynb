# %%
import numpy as np
import pandas as pd
defense_2019 = pd.read_csv('Defense_2019.csv')
defense_2020 = pd.read_csv('Defense_2020.csv')
defense_2021 = pd.read_csv('Defense_2021.csv')
defense_2022 = pd.read_csv('Defense_2022.csv')
defense_2023 = pd.read_csv('Defense_2023.csv')
defense_2024 = pd.read_csv('Defense_2024.csv')

# %%
total_defense = pd.concat([defense_2019, defense_2020, defense_2021, defense_2022, defense_2023, defense_2024], axis=0)
total_defense
# Out:
#       Rank               Name Team Position  Games Played  Solo Tackles  \
# 0        1       Bobby Wagner  SEA       LB            16            86
# 1        2     Blake Martinez   GB       LB            16            97
# 2        3       Jordan Hicks  ARI       LB            16            92
# 3        4        Budda Baker  ARI        S            16           104
# 4        5       Luke Kuechly  CAR       LB            16            81
# ...    ...                ...  ...      ...           ...           ...
# 1398  1463  Kingsley Jonathan  BUF       DE             1             0
# 1399  1463  Calvin Austin III  PIT       WR             9             0
# 1400  1463       Casey Rogers  NYG       DT             2             0
# 1401  1463  Dwight McGlothern  MIN       CB             5             0
# 1402  1463       Jose Ramirez   TB       LB             4             0
#
#       Assist Tackles  Total Tackles  Sacks  Sack Yards  Tackles for Loss  \
# ...

# %%
total_defense.to_csv("Total_Defense.csv", index = False)
print("Data saved to Total_Defense.csv")
# Out:
# Data saved to Total_Defense.csv
