# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.nflpenalties.com/all-players.php?view=reg_season&year=2022'

# Call the GET request
requests = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(requests.text, "html.parser")

# examined HTML output using inspect to find where data is
columns = ['Name', 'Position', 'Team', 'Penalty Count', 'Yards', 'Declined', 'Offsetting', 'Total Flags', 'Pre-Snap', 'Count per Game', 'Yards per Game', 'Percent of Team', 'Penalty Types']
player_penalties_df_2022 = pd.DataFrame(columns = columns)

penalties_div = soup.find(name = 'div', attrs = {'class' : 'inner'})
table = penalties_div.find("table") 
tbody = table.find("tbody")  # Get the tbody element
rows = tbody.find_all("tr")  # Find all table rows

for row in rows:
    cols = row.find_all("td")  # Get all table data cells
    data = [col.text.strip() for col in cols]  # Extract text from each column
    penalty_series = pd.Series(data, index = columns)
    player_penalties_df_2022 = pd.concat([player_penalties_df_2022, penalty_series.to_frame().T], ignore_index=True)

display(player_penalties_df_2022)

player_penalties_df_2022.to_csv("2022_Player_Penalties.csv", index = False)
print("Data saved to 2022_Player_Penalties.csv")
# Out:
#             Name Position           Team Penalty Count Yards Declined  \
# 0    L.Dickerson       OL   Philadelphia            13    89        1
# 1        T.Brown       OL    New England             9    60        2
# 2       I.Ekwonu       OL       Carolina            10    71        2
# 3      Tyl.Smith       OL         Dallas             9    70        4
# 4        D.Smith       OL      Tampa Bay            12   100        0
# ..           ...      ...            ...           ...   ...      ...
# 231    S.Burford       OL  San Francisco             4    30        0
# 232     C.Holmes       DB     Washington             4    32        0
# 233    A.Norwell       OL     Washington             4    30        0
# 234     C.Harris       DB    New Orleans             4    17        0
# 235  T.Hockenson       TE      Minnesota             4    34        0
#
#     Offsetting Total Flags Pre-Snap Count per Game Yards per Game  \
# 0            0          14        4           0.65           4.45
# 1            2          13        5           0.53           3.53
# 2            1          13        4           0.59           4.18
# 3            0          13        4           0.47           3.68
# 4            0          12        4           0.67           5.56
# ..         ...         ...      ...            ...            ...
# 231          0           4        1           0.20           1.50
# 232          0           4        0           0.24           1.88
# 233          0           4        1           0.24           1.76
# 234          0           4        0           0.24           1.00
# 235          0           4        1           0.22           1.89
#
#     Percent of Team                                      Penalty Types
# 0             12.84  Offensive Holding (7), False Start (4), Inelig...
# 1             12.50  Offensive Holding (6), False Start (5), Trippi...
# 2             12.50  Offensive Holding (7), False Start (4), Illega...
# 3             10.92             Offensive Holding (9), False Start (4)
# 4             11.65  Offensive Holding (7), False Start (4), Illega...
# ..              ...                                                ...
# 231            3.60  Offensive Holding (2), False Start (1), Inelig...
# 232            4.21               Offensive Holding (3), Face Mask (1)
# 233            4.21  Offensive Holding (2), False Start (1), Illega...
# 234            4.04  Defensive Holding (2), Unnecessary Roughness (...
# 235            4.35  Offensive Pass Interference (2), False Start (...
#
# [236 rows x 13 columns]
# Data saved to 2022_Player_Penalties.csv
