# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.nflpenalties.com/all-players.php?view=reg_season&year=2024'

# Call the GET request
requests = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(requests.text, "html.parser")

# examined HTML output using inspect to find where data is
columns = ['Name', 'Position', 'Team', 'Penalty Count', 'Yards', 'Declined', 'Offsetting', 'Total Flags', 'Pre-Snap', 'Count per Game', 'Yards per Game', 'Percent of Team', 'Penalty Types']
player_penalties_df_2024 = pd.DataFrame(columns = columns)

penalties_div = soup.find(name = 'div', attrs = {'class' : 'inner'})
table = penalties_div.find("table") 
tbody = table.find("tbody")  # Get the tbody element
rows = tbody.find_all("tr")  # Find all table rows

for row in rows:
    cols = row.find_all("td")  # Get all table data cells
    data = [col.text.strip() for col in cols]  # Extract text from each column
    penalty_series = pd.Series(data, index = columns)
    player_penalties_df_2024 = pd.concat([player_penalties_df_2024, penalty_series.to_frame().T], ignore_index=True)

display(player_penalties_df_2024)

player_penalties_df_2024.to_csv("2024_Player_Penalties.csv", index = False)
print("Data saved to 2024_Player_Penalties.csv")
# Out:
#           Name Position         Team Penalty Count Yards Declined Offsetting  \
# 0     L.Tunsil       OL      Houston            17    95        1          1
# 1     T.Guyton       OL       Dallas            14   100        2          2
# 2     J.Taylor       OL  Kansas City            14   100        2          1
# 3     G.Bolles       OL       Denver            12   100        2          2
# 4      S.Brown       OL      Buffalo            13   105        1          2
# ..         ...      ...          ...           ...   ...      ...        ...
# 729   A.Cooper       WR      Buffalo             2    15        0          0
# 730  J.Windmon       LB     Carolina             2    20        0          0
# 731   J.Hardee       DB    Tennessee             2    10        0          0
# 732   M.Wilson       DB   Cincinnati             2     6        0          0
# 733     J.Ford       DL      Chicago             2    10        0          0
#
#     Total Flags Pre-Snap Count per Game Yards per Game Percent of Team  \
# 0            19       15           0.89           5.00           13.87
# 1            18        8           0.82           5.88           14.06
# 2            17        9           0.70           5.00           15.45
# 3            16        7           0.67           5.56           14.41
# 4            16        7           0.65           5.25           12.70
# ..          ...      ...            ...            ...             ...
# 729           2        1           0.10           0.75            1.59
# 730           2        1           0.12           1.18            1.69
# 731           2        2           0.12           0.59            1.52
# 732           2        0           0.12           0.35            1.98
# 733           2        2           0.12           0.59            1.82
#
#                                          Penalty Types
# 0    False Start (12), Illegal Formation (3), Offen...
# 1    Offensive Holding (8), False Start (5), Illega...
# 2    Offensive Holding (7), False Start (6), Illega...
# 3    Offensive Holding (6), Illegal Formation (4), ...
# 4    False Start (6), Offensive Holding (6), Unnece...
# ..                                                 ...
# 729   False Start (1), Offensive Pass Interference (1)
# 730         Illegal Formation (1), Hip Drop Tackle (1)
# 731             False Start (1), Illegal Formation (1)
# 732  Defensive Pass Interference (1), Defensive Hol...
# 733      Encroachment (1), Neutral Zone Infraction (1)
#
# [734 rows x 13 columns]
# Data saved to 2024_Player_Penalties.csv
