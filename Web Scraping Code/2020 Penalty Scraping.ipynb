# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.nflpenalties.com/all-players.php?view=reg_season&year=2020'

# Call the GET request
requests = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(requests.text, "html.parser")

# %%
# examined HTML output using inspect to find where data is
columns = ['Name', 'Position', 'Team', 'Penalty Count', 'Yards', 'Declined', 'Offsetting', 'Total Flags', 'Pre-Snap', 'Count per Game', 'Yards per Game', 'Percent of Team', 'Penalty Types']
player_penalties_df_2020 = pd.DataFrame(columns = columns)

penalties_div = soup.find(name = 'div', attrs = {'class' : 'inner'})
table = penalties_div.find("table") 
tbody = table.find("tbody")  # Get the tbody element
rows = tbody.find_all("tr")  # Find all table rows

for row in rows:
    cols = row.find_all("td")  # Get all table data cells
    data = [col.text.strip() for col in cols]  # Extract text from each column
    penalty_series = pd.Series(data, index = columns)
    player_penalties_df_2020 = pd.concat([player_penalties_df_2020, penalty_series.to_frame().T], ignore_index=True)

display(player_penalties_df_2020)
# Out:
#            Name Position       Team Penalty Count Yards Declined Offsetting  \
# 0    P.Peterson       CB    Arizona            10   114        4          0
# 1       J.Wills       OL  Cleveland            11    70        0          0
# 2       D.Smith       OL  Tampa Bay             9    70        0          1
# 3       A.Hicks       DT    Chicago             8    62        2          0
# 4       M.Judon       LB  Baltimore             8    72        2          0
# ..          ...      ...        ...           ...   ...      ...        ...
# 208     B.Shell        T    Seattle             4    24        0          0
# 209   S.Kindley       OL      Miami             4    30        0          0
# 210  M.Hennessy       OL    Atlanta             4    35        0          0
# 211   J.Johnson       DB    Chicago             4    76        0          0
# 212    J.Kearse       DB    Detroit             4    40        0          0
#
#     Total Flags Pre-Snap Count per Game Yards per Game Percent of Team  \
# 0            14        2           0.63           7.13           12.39
# 1            11        8           0.61           3.89           10.38
# 2            10        3           0.45           3.50            9.90
# 3            10        2           0.47           3.65           10.31
# 4            10        6           0.44           4.00            8.55
# ..          ...      ...            ...            ...             ...
# 208           4        3           0.24           1.41            4.30
# 209           4        2           0.25           1.88            5.41
# 210           4        1           0.25           2.19            4.82
# 211           4        0           0.24           4.47            4.12
# 212           4        0           0.25           2.50            4.17
#
#                                          Penalty Types
# 0    Defensive Holding (7), Defensive Pass Interfer...
# 1               False Start (8), Offensive Holding (3)
# 2    Offensive Holding (6), False Start (3), Inelig...
# 3    Roughing the Passer (3), Illegal Use of Hands ...
# 4    Defensive Offside (6), Roughing the Passer (2)...
# ..                                                 ...
# 208             False Start (3), Offensive Holding (1)
# 209             False Start (2), Offensive Holding (2)
# 210             Offensive Holding (3), False Start (1)
# 211  Defensive Pass Interference (3), Illegal Conta...
# 212  Defensive Holding (2), Unnecessary Roughness (...
#
# [213 rows x 13 columns]

# %%
player_penalties_df_2020.to_csv("2020_Player_Penalties.csv", index = False)
print("Data saved to 2020_Player_Penalties.csv")
# Out:
# Data saved to 2020_Player_Penalties.csv
