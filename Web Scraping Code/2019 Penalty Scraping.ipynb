# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.nflpenalties.com/all-players.php?year=2019&view=reg_season'

# Call the GET request
requests = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(requests.text, "html.parser")

# %%
# examined HTML output using inspect to find where data is
columns = ['Name', 'Position', 'Team', 'Penalty Count', 'Yards', 'Declined', 'Offsetting', 'Total Flags', 'Pre-Snap', 'Count per Game', 'Yards per Game', 'Percent of Team', 'Penalty Types']
player_penalties_df_2019 = pd.DataFrame(columns = columns)

penalties_div = soup.find(name = 'div', attrs = {'class' : 'inner'})
table = penalties_div.find("table") 
tbody = table.find("tbody")  # Get the tbody element
rows = tbody.find_all("tr")  # Find all table rows

for row in rows:
    cols = row.find_all("td")  # Get all table data cells
    data = [col.text.strip() for col in cols]  # Extract text from each column
    penalty_series = pd.Series(data, index = columns)
    player_penalties_df_2019 = pd.concat([player_penalties_df_2019, penalty_series.to_frame().T], ignore_index=True)

display(player_penalties_df_2019)
# Out:
#             Name Position           Team Penalty Count Yards Declined  \
# 0       L.Tunsil       OL        Houston            15    80        3
# 1       G.Bolles       OL         Denver            10    95        6
# 2       J.Taylor       OL   Jacksonville            15   120        0
# 3    A.Whitworth       OL        LA Rams            13   125        1
# 4    D.Humphries       OL        Arizona            12    82        1
# ..           ...      ...            ...           ...   ...      ...
# 275    M.Purcell       DL         Denver             4    35        0
# 276    E.Sanders       WR  San Francisco             4    30        0
# 277      R.Evans       LB      Tennessee             4    36        0
# 278    A.Corbett       OL        LA Rams             4    20        0
# 279     D.Hodges       QB     Pittsburgh             4    27        0
#
#     Offsetting Total Flags Pre-Snap Count per Game Yards per Game  \
# 0            0          18       12           0.83           4.44
# 1            1          17        2           0.63           5.94
# 2            0          15        5           0.94           7.50
# 3            0          14        1           0.81           7.81
# 4            0          13        5           0.75           5.13
# ..         ...         ...      ...            ...            ...
# 275          0           4        1           0.25           2.19
# 276          0           4        2           0.21           1.58
# 277          0           4        0           0.21           1.89
# 278          0           4        4           0.25           1.25
# 279          0           4        2           0.25           1.69
#
#     Percent of Team                                      Penalty Types
# 0             14.75  False Start (12), Offensive Holding (3), Ineli...
# 1             15.32  Offensive Holding (13), False Start (2), Unnec...
# 2             11.36  Offensive Holding (9), False Start (5), Inelig...
# 3             11.86  Offensive Holding (10), Illegal Use of Hands (...
# 4             10.74  False Start (5), Offensive Holding (5), Illega...
# ..              ...                                                ...
# 275            3.60  Unnecessary Roughness (1), Roughing the Passer...
# 276            3.42  False Start (2), Illegal Block Above the Waist...
# 277            3.42  Unnecessary Roughness (1), Defensive Pass Inte...
# 278            3.39                                    False Start (4)
# 279            3.60  Intentional Grounding (2), False Start (1), Il...
#
# [280 rows x 13 columns]

# %%
player_penalties_df_2019.to_csv("2019_Player_Penalties.csv", index = False)
print("Data saved to 2019_Player_Penalties.csv")
# Out:
# Data saved to 2019_Player_Penalties.csv
